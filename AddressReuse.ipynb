# %%
import os
import pandas as pd
import numpy as np
import datetime

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

import chart_utils
import analysis_utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv("./data/address_reuse.csv")

# %%
data
# Out:
#             date  address_count  new_address_count  reused_address_count  \
# 0     2009-01-03              1                  1                     0
# 1     2009-01-09             14                 14                     0
# 2     2009-01-10             61                 61                     0
# 3     2009-01-11             93                 93                     0
# 4     2009-01-12            106                101                     5
# ...          ...            ...                ...                   ...
# 4551  2021-06-25         711510             369003                342507
# 4552  2021-06-26         618436             325778                292658
# 4553  2021-06-27         452222             227488                224734
# 4554  2021-06-28         726582             388157                338425
# 4555  2021-06-29         127627              67165                 60462
#
#       pct_reused_count  address_ucount  new_address_ucount  \
# ...

# %%
data.columns
# Out:
# Index(['date', 'address_count', 'new_address_count', 'reused_address_count',
#        'pct_reused_count', 'address_ucount', 'new_address_ucount',
#        'reused_address_ucount', 'pct_reused_ucount', 'address_value',
#        'new_address_value', 'reused_address_value', 'pct_reused_value',
#        'address_count_small', 'new_address_count_small',
#        'reused_address_count_small', 'pct_reused_count_small',
#        'address_ucount_small', 'new_address_ucount_small',
#        'reused_address_ucount_small', 'pct_reused_ucount_small',
#        'address_value_small', 'new_address_value_small',
#        'reused_address_value_small', 'pct_reused_value_small'],
#       dtype='object')

# %%
data['pct_reused_ucount_small_28d'] = data['pct_reused_ucount_small'].rolling(28).mean()
data['pct_reused_ucount_small_7d'] = data['pct_reused_ucount_small'].rolling(7).mean()

# %%
chart_utils.single_axis_chart2(
    data.loc[data.date >= '2012-01-01'], x_series='date', 
    y_series='pct_reused_ucount_small_7d',
    x_axis_title='Date',
    y_series_axis_format= ',.2%',
    y_series_title='% Addresses Reused',
    title='Bitcoin Address Reuse',
    data_source="Proprietary",
    halving_lines=False,
)
# Out:
# <div>                            <div id="3f0f6e75-359e-47b0-98a7-4777c95b20d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f0f6e75-359e-47b0-98a7-4777c95b20d9")) {                    Plotly.newPlot(                        "3f0f6e75-359e-47b0-98a7-4777c95b20d9",                        [{"marker": {"color": "rgb(242, 169, 0)"}, "name": "pct_reused_ucount_small_7d", "type": "scatter", "x": ["2012-01-01", "2012-01-02", "2012-01-03", "2012-01-04", "2012-01-05", "2012-01-06", "2012-01-07", "2012-01-08", "2012-01-09", "2012-01-10", "2012-01-11", "2012-01-12", "2012-01-13", "2012-01-14", "2012-01-15", "2012-01-16", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-21", "2012-01-22", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26"
# ...
